# %%
from htbayes import BEST
# Out:
# WARNING (theano.configdefaults): g++ not detected ! Theano will be unable to execute optimized C-implementations (for both CPU and GPU) and will default to Python implementations. Performance will be severely degraded. To remove this warning, set Theano flags cxx to an empty string.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

df = pd.read_csv("master_datafile.csv", index_col="SampleID")
#df = df.loc[["Mock", "Vic", "PHH", "L1", "L3", "L4", "L6", "L7", "L11", "L12", "L16", "L17", "L18", "L19", "L20","L22","L23", "L24", "L26"]]
df = df.loc[["Vic", "1:02", "1:04", "1:08"]]
df = df.reset_index()
df
# Out:
#    SampleID  Unnamed: 0  Well  Replicate  Well Type        Date  Luminescence  \
# 0       Vic           0   1.0        1.0       12.0  20160927.0    633321.368
# 1       Vic           1   2.0        2.0       12.0  20160927.0    657692.368
# 2       Vic          16   5.0        1.0       12.0  20161003.0    537143.653
# 3       Vic          27   4.0        1.0       12.0  20161115.0   1022500.075
# 4       Vic          74  51.0        1.0       96.0  20161115.0    216877.582
# 5       Vic          75  52.0        2.0       96.0  20161115.0     91720.182
# 6       Vic          76   2.0        1.0       96.0  20161122.0    714840.915
# 7       Vic          77   3.0        2.0       96.0  20161122.0   1127536.915
# 8      1:02          78   4.0        1.0       96.0  20161122.0    594664.915
# 9      1:02          79   5.0        2.0       96.0  20161122.0    463781.915
# 10     1:02          80   6.0        3.0       96.0  20161122.0    496747.915
# 11     1:04          81   7.0        1.0       96.0  20161122.0    121855.915
# 12     1:04          82   8.0        2.0       96.0  20161122.0    128321.915
# 13     1:04          83   9.0        3.0       96.0  20161122.0    169972.915
# 14     1:08          84  10.0        1.0       96.0  20161122.0     70252.215
# 15     1:08          85  11.0        2.0       96.0  20161122.0     19088.515
# 16     1:08          86  12.0        3.0       96.0  20161122.0       454.574
#
#     Normalized to Negative   Vlumins
# 0             1.271967e+03  1.000000
# 1             1.320914e+03  1.038481
# 2             4.472194e+02  1.000000
# 3             1.022500e+06  1.000000
# 4             1.026912e+03  1.000000
# 5             4.342935e+02  0.422912
# 6             6.240100e+03  1.000000
# 7             9.842670e+03  1.577326
# 8             5.191041e+03  0.831884
# 9             4.048517e+03  0.648790
# 10            4.336289e+03  0.694907
# 11            1.063724e+03  0.170466
# 12            1.120168e+03  0.179511
# 13            1.483754e+03  0.237777
# 14            6.132565e+02  0.098277
# 15            1.666304e+02  0.026703
# 16            3.968138e+00  0.000636

# %%
#plotting
plt.figure(figsize=(12,4))
plt.title("Effect of cell density", fontsize = 20)
sns.boxplot(data=df, x="SampleID", y="Vlumins")
#plt.xticks(rotation=90)
